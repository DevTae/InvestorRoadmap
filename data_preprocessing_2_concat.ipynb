# %%
import pandas as pd
import os

fs_local = r'C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\재무상태표'
cf_local = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\현금흐름표"
ci_local = r'C:\Users\user\OneDrive\바탕 화면\db 공모전\data\2분기\포괄손익계산서'
corp_code_local = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\corp_code.csv"

fs_local_files = [f for f in os.listdir(fs_local) if f.endswith('.csv')]
cf_local_files = [f for f in os.listdir(cf_local) if f.endswith('.csv')]
corp_codes = pd.read_csv(corp_code_local)
print(corp_codes)
# Out:
#           종목코드       회사명
# 0     [000020]      동화약품
# 1     [000040]     KR모터스
# 2     [000050]        경방
# 3     [000070]     삼양홀딩스
# 4     [000080]     하이트진로
# ...        ...       ...
# 1862  [900250]   크리스탈신소재
# 1863  [900260]       로스웰
# 1864  [900280]     골든센츄리
# 1865  [900300]  오가닉티코스메틱
# 1866  [950110]    SBI액시즈
#
# [1867 rows x 2 columns]

# %%
sample = pd.read_excel(r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\1분기\현금흐름표\2023_1분기보고서_04_현금흐름표_연결_20231223.xlsx")
display(sample)
sample.to_csv(r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\1분기\현금흐름표\2023_1분기보고서_04_현금흐름표_연결_20231223.csv",index=False, encoding='euc-kr')
# Out:
#                     재무제표종류      종목코드 회사명       시장구분   업종            업종명  결산월  \
# 0      현금흐름표, 간접법 - 연결재무제표  [060310]  3S  코스닥시장상장법인  262      전자 부품 제조업    3
# 1      현금흐름표, 간접법 - 연결재무제표  [060310]  3S  코스닥시장상장법인  262      전자 부품 제조업    3
# 2      현금흐름표, 간접법 - 연결재무제표  [060310]  3S  코스닥시장상장법인  262      전자 부품 제조업    3
# 3      현금흐름표, 간접법 - 연결재무제표  [060310]  3S  코스닥시장상장법인  262      전자 부품 제조업    3
# 4      현금흐름표, 간접법 - 연결재무제표  [060310]  3S  코스닥시장상장법인  262      전자 부품 제조업    3
# ...                    ...       ...  ..        ...  ...            ...  ...
# 74285  현금흐름표, 간접법 - 연결재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
# 74286  현금흐름표, 간접법 - 연결재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
# 74287  현금흐름표, 간접법 - 연결재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
# 74288  현금흐름표, 간접법 - 연결재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
# 74289  현금흐름표, 간접법 - 연결재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
#
#            결산기준일   보고서종류   통화  \
# ...

# %% [markdown]
# 재무상태표 업로딩

# %%
import glob
import pandas as pd

def read_csv_files(directory_path):
    # 지정된 디렉토리에서 모든 CSV 파일 찾기
    csv_files = glob.glob(f'{directory_path}/*.csv')

    # CSV 파일을 저장할 리스트 초기화
    data_frames = []

    # 각 CSV 파일을 읽어서 리스트에 추가
    for csv_file in csv_files:
        try:
            # CSV 파일을 DataFrame으로 읽기
            df = pd.read_csv(csv_file, encoding='euc-kr')
            
            # DataFrame을 리스트에 추가
            data_frames.append(df)
        except pd.errors.EmptyDataError:
            # 빈 CSV 파일의 경우 예외 처리
            print(f"Warning: {csv_file} is empty.")

    return data_frames

# CSV 파일이 있는 디렉토리 경로 지정
directory_path = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\2분기\재무상태표"

# CSV 파일들을 읽어와서 리스트에 담기
fs_local_files = read_csv_files(directory_path)

# 리스트에 있는 데이터 프레임들을 확인하거나 처리할 수 있습니다.
for df in fs_local_files:
    print(df)
# Out:
#              재무제표종류      종목코드       회사명       시장구분   업종     업종명  결산월  \
# 0    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 1    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 2    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 3    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 4    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 5    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 6    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 7    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 8    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 9    재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 10   재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 11   재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# 12   재무상태표, 기타 - 연결  [289080]  SV인베스트먼트  코스닥시장상장법인  649  기타 금융업    3
# ...

# %% [markdown]
# 현금흐름표 업로딩

# %%
import glob
import pandas as pd

def read_csv_files(directory_path):
    # 지정된 디렉토리에서 모든 CSV 파일 찾기
    csv_files = glob.glob(f'{directory_path}/*.csv')

    # CSV 파일을 저장할 리스트 초기화
    data_frames = []

    # 각 CSV 파일을 읽어서 리스트에 추가
    for csv_file in csv_files:
        try:
            # CSV 파일을 DataFrame으로 읽기
            df = pd.read_csv(csv_file, encoding='euc-kr')
            
            # DataFrame을 리스트에 추가
            data_frames.append(df)
        except pd.errors.EmptyDataError:
            # 빈 CSV 파일의 경우 예외 처리
            print(f"Warning: {csv_file} is empty.")

    return data_frames

# CSV 파일이 있는 디렉토리 경로 지정
directory_path = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\현금흐름표"

# CSV 파일들을 읽어와서 리스트에 담기
cf_local_files = read_csv_files(directory_path)

# 리스트에 있는 데이터 프레임들을 확인하거나 처리할 수 있습니다.
# for df in cf_local_files:
#     print(df)
print(len(cf_local_files))
# Out:
# 5

# %% [markdown]
# 포괄손익계산서 업로딩

# %%
import glob
import pandas as pd

def read_csv_files(directory_path):
    # 지정된 디렉토리에서 모든 CSV 파일 찾기
    csv_files = glob.glob(f'{directory_path}/*.csv')

    # CSV 파일을 저장할 리스트 초기화
    data_frames = []

    # 각 CSV 파일을 읽어서 리스트에 추가
    for csv_file in csv_files:
        try:
            # CSV 파일을 DataFrame으로 읽기
            df = pd.read_csv(csv_file, encoding='euc-kr')
            
            # DataFrame을 리스트에 추가
            data_frames.append(df)
        except pd.errors.EmptyDataError:
            # 빈 CSV 파일의 경우 예외 처리
            print(f"Warning: {csv_file} is empty.")

    return data_frames

# CSV 파일이 있는 디렉토리 경로 지정
directory_path = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\2분기\포괄손익계산서"

# CSV 파일들을 읽어와서 리스트에 담기
ci_local_files = read_csv_files(directory_path)

# 리스트에 있는 데이터 프레임들을 확인하거나 처리할 수 있습니다.
# for df in cf_local_files:
#     print(df)
print(len(ci_local_files))
# Out:
# 3

# %%
cf_total = pd.concat(cf_local_files, axis=0, ignore_index=True)

cf_total.to_csv(r'C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\현금흐름표\2023_3분기보고서_04_현금흐름표_total.csv',index=False, encoding='euc-kr')

# %%
fs_total = pd.concat(fs_local_files, axis=0, ignore_index=True)
fs_total.to_csv(r'C:\Users\user\OneDrive\바탕 화면\db 공모전\data\2분기\재무상태표\2023_2분기보고서_01_재무상태표_total.csv',index=False, encoding='euc-kr')

# %%
ci_total = pd.concat(ci_local_files, axis=0, ignore_index=True)
ci_total.to_csv(r'C:\Users\user\OneDrive\바탕 화면\db 공모전\data\2분기\포괄손익계산서\2023_2분기보고서_03_포괄손익계산서_total.csv',index=False, encoding='euc-kr')

# %%
import pandas as pd

fs_total = pd.read_csv(r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\재무상태표\2023_3분기보고서_01_재무상태표_total.csv", encoding='euc-kr')
cf_total = pd.read_csv(r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\현금흐름표\2023_3분기보고서_04_현금흐름표_total.csv", encoding= 'euc-kr')
corp_code_local = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\corp_code.csv"
ci_total = pd.read_csv(r'C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\포괄손익계산서\2023_3분기보고서_03_포괄손익계산서_total.csv', encoding= 'euc-kr')
corp_codes = pd.read_csv(corp_code_local)

# %%
#for index, row in cf_total.iterrows() :
    #row['항목명'] = row['항목명'].str.strip()

cf_total['항목명'] =cf_total['항목명'].str.strip()
cf_total = cf_total[cf_total['항목명'] != '당기순이익(손실)']
cf_total = cf_total[cf_total['항목명'] != '반기순이익(손실)']
fs_total['항목명'] =fs_total['항목명'].str.strip()
ci_total['항목명'] =ci_total['항목명'].str.strip()

# %%
ci_total = ci_total.rename(columns={'당기 3분기 3개월' : '당기 3분기'})
fs_total = fs_total.rename(columns={'당기 3분기말' : '당기 3분기'})

cf_total =cf_total.drop(['재무제표종류','시장구분','업종','업종명','결산월','결산기준일','보고서종류','통화','항목코드','전기 3분기', '전기', '전전기'], axis=1)
fs_total = fs_total.drop(['재무제표종류','시장구분','업종','업종명','결산월','결산기준일','보고서종류','통화','항목코드','전기말','전전기말','Unnamed: 15'], axis=1)
ci_total = ci_total.drop(['재무제표종류','시장구분','업종','업종명','결산월','결산기준일','보고서종류','통화','항목코드','당기 3분기 누적','전기 3분기 3개월','전기 3분기 누적', '전기', '전전기'], axis=1)
display(cf_total)
display(fs_total)
display(ci_total)
# Out:
#            종목코드      회사명                           항목명        당기 3분기
# 0      [138930]  BNK금융지주                    기초현금및현금성자산  5.894730e+12
# 1      [138930]  BNK금융지주                    기말현금및현금성자산  4.343900e+12
# 2      [138930]  BNK금융지주                     재무활동순현금흐름  6.438140e+11
# 3      [138930]  BNK금융지주                    신종자본증권의 발행  1.494880e+11
# 4      [138930]  BNK금융지주                    신종자본증권의 상환  2.500000e+11
# ...         ...      ...                           ...           ...
# 87865  [001500]    현대차증권                     법인세납부(환급)  2.189340e+10
# 87866  [001500]    현대차증권                          이자지급  2.493350e+11
# 87867  [001500]    현대차증권                          이자수취  3.283740e+11
# 87868  [001500]    현대차증권           현금및현금성자산에 대한 환율변동효과  5.504173e+08
# 87869  [001500]    현대차증권  환율변동효과 반영전 현금및현금성자산의 순증가(감소)  8.323478e+10
#
# [86976 rows x 4 columns]
#             종목코드      회사명                   항목명        당기 3분기
# ...

# %% [markdown]
# 시가총액 데이터 업로딩

# %%
import glob
import pandas as pd

def read_csv_files(directory_path):
    # 지정된 디렉토리에서 모든 CSV 파일 찾기
    csv_files = glob.glob(f'{directory_path}/*.csv')

    # CSV 파일을 저장할 리스트 초기화
    data_frames = []

    # 각 CSV 파일을 읽어서 리스트에 추가
    for csv_file in csv_files:
        try:
            # CSV 파일을 DataFrame으로 읽기
            df = pd.read_csv(csv_file)
            
            # DataFrame을 리스트에 추가
            data_frames.append(df)
        except pd.errors.EmptyDataError:
            # 빈 CSV 파일의 경우 예외 처리
            print(f"Warning: {csv_file} is empty.")

    return data_frames

# CSV 파일이 있는 디렉토리 경로 지정
directory_path = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\price_stat_datas"

# CSV 파일들을 읽어와서 리스트에 담기
marketcap_data = read_csv_files(directory_path)

# 리스트에 있는 데이터 프레임들을 확인하거나 처리할 수 있습니다.
# for df in cf_local_files:
#     print(df)
# print(len(marketcap_data))
print(marketcap_data)
# Out:
# [     ATR     MARKETCAP  TSF_SLOPE
# 0  0.017  2.321105e+11     -0.127,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.027  2.902080e+11      0.354,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.028  2.737284e+11     -0.024,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.023  2.868562e+11      0.009,     ATR     MARKETCAP  TSF_SLOPE
# 0  0.03  4.845378e+10     -0.125,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.066  5.691397e+10     -0.006,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.071  8.200613e+10      0.385,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.055  3.441758e+10     -0.471,     ATR     MARKETCAP  TSF_SLOPE
# 0  0.02  2.936175e+11      0.007,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.019  2.725077e+11     -0.073,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.026  2.324815e+11     -0.118,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.036  2.423510e+11      0.119,      ATR     MARKETCAP  TSF_SLOPE
# 0  0.024  6.448898e+11      0.114,      ATR     MARKETCAP  TSF_SLOPE
# ...

# %%
import os

# 파일 위치를 변수로 지정
directory_path = r"C:\Users\user\Downloads\price_stat_datas" # 여기에 실제 디렉토리 경로를 입력하세요.

# 해당 디렉토리의 파일 목록 가져오기
file_list = os.listdir(directory_path)

# CSV 파일들의 이름을 담을 리스트 초기화
price_files = []

# 각 파일에 대해 확인
for file in file_list:
    if file.endswith('.csv'):
        price_files.append(file)

# CSV 파일 목록 출력
print(f"{directory_path} 디렉토리에 있는 CSV 파일 목록:")
print(price_files)

for i in price_files :
    file_path = r"C:\Users\user\Downloads\price_stat_datas\{}".format(i)
    file_end = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\price\{}".format(i)
    sample =pd.read_csv(file_path)
    if '_3_' in i :
        sample.to_csv(file_end)
# Out:
# C:\Users\user\Downloads\price_stat_datas 디렉토리에 있는 CSV 파일 목록:
# ...

# %%
import os

# 파일 위치를 변수로 지정
directory_path = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\price" # 여기에 실제 디렉토리 경로를 입력하세요.

# 해당 디렉토리의 파일 목록 가져오기
file_list = os.listdir(directory_path)

# CSV 파일들의 이름을 담을 리스트 초기화
price_files = []

# 각 파일에 대해 확인
for file in file_list:
    if file.endswith('.csv'):
        price_files.append(file)

# CSV 파일 목록 출력
print(f"{directory_path} 디렉토리에 있는 CSV 파일 목록:")
print(price_files)
# Out:
# C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\price 디렉토리에 있는 CSV 파일 목록:
# ...

# %%
for i in price_files :
    corp_code = '['+i[:6]+']'
    fs_total_sample = fs_total.loc[fs_total['종목코드'] == corp_code]
    cf_total_sample = cf_total.loc[cf_total['종목코드'] == corp_code]
    ci_total_sample = ci_total.loc[ci_total['종목코드'] == corp_code]
    corp_code = corp_code[1:-1]
    marketcap_data_path = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\price\{}_3_price.csv".format(corp_code)
    marketcap_data = pd.read_csv(marketcap_data_path)
    fs_cf_total = pd.concat([fs_total_sample, cf_total_sample, ci_total_sample], axis=0, ignore_index= True)
    fs_cf_total= fs_cf_total.drop(['종목코드', '회사명'], axis=1).set_index('항목명').T
    fs_cf_total = fs_cf_total.dropna(axis=1)
    total_data = pd.concat([fs_cf_total, marketcap_data], axis=1)
    total_data = total_data.sum(axis=0, skipna= True)
    total_data = pd.DataFrame(total_data).T
    total_data_path = r'C:\Users\user\OneDrive\바탕 화면\db 공모전\data\3분기\pre_data\2023_3\{}_3.csv'.format(corp_code)
    total_data.to_csv(total_data_path, encoding='euc-kr')

# %%
corp_code = '005930'
marketcap_data_path = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\price_stat_datas\{}_1_price.csv".format(corp_code)
marketcap = pd.read_csv(marketcap_data_path)
marketcap['MARKETCAP']

marketcap_data = float(marketcap['MARKETCAP'].replace(',',''))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19400\438056615.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   marketcap_data = float(marketcap['MARKETCAP'].replace(',',''))

# %%
samsung = r"C:\Users\user\OneDrive\바탕 화면\db 공모전\data\1분기\pre_data\2023_1_2\005930_1.csv"

samsung = pd.read_csv(samsung, encoding='euc-kr')
#display(samsung)
#samsung = samsung.astype(float)
samsung = samsung.dropna(axis=1)
samsung_earning = samsung['당기순이익(손실)']


display(marketcap)
display(samsung['당기순이익(손실)'])
display(samsung['당기순이익'])
per = float(marketcap['MARKETCAP'])/float(samsung['당기순이익'])
print(per)
# Out:
#      ATR        MARKETCAP  TSF_SLOPE
# 0  0.017  382065758552038      0.028
# 0    1.574600e+12
# Name: 당기순이익(손실), dtype: float64
# 0    1.574600e+12
# Name: 당기순이익, dtype: float64
# 242.64305763497904
# C:\Users\user\AppData\Local\Temp\ipykernel_19400\2848243578.py:13: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   per = float(marketcap['MARKETCAP'])/float(samsung['당기순이익'])
